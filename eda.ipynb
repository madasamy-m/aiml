# %%
print("hello")
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\Users\acer\Music\anaconda\Lib\site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\acer\Music\anaconda\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\acer\Music\anaconda\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\acer\Music\anaconda\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\acer\Music\anaconda\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\acer\Music\anaconda\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\Users\acer\Music\anaconda\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\acer\Music\anaconda\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\Users\acer\Music\anaconda\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\acer\Music\anaconda\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\acer\Music\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\acer\Music\anaconda\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\acer\Music\anaconda\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score

# %%
df = pd.read_csv("appliance_energy.csv")
df.head()
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
print(df.isnull().sum())
df=df.dropna()
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_csv("C:/Users/acer/Documents/csv file/appliance_energy (1).csv")

# %%
print(df.isnull)
# Out:
# <bound method DataFrame.isnull of     Temperature (°C)  Energy Consumption (kWh)
# 0          22.490802                  2.292604
# 1          34.014286                  3.251925
# 2          29.639879                  3.009868
# 3          26.973170                  1.703533
# 4          18.120373                  1.702201
# ..               ...                       ...
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374
#
# [100 rows x 2 columns]>

# %%
X = df[['Temperature (°C)']]
Y = df['Energy Consumption (kWh)']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)



model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
#     Temperature (°C)
# 55         33.437485
# 88         32.744255
# 26         18.993476
# 42         15.687770
# 69         34.737739
# ..               ...
# 60         22.773546
# 71         18.974314
# 14         18.636499
# 92         30.215701
# 51         30.502656
#
# [80 rows x 1 columns]
#     Temperature (°C)
# 83         16.271167
# 53         32.896547
# 70         30.444895
# 45         28.250446
# 44         20.175600
# 39         23.803050
# 22         20.842893
# 80         32.262069
# 10         15.411690
# 0          22.490802
# 18         23.638900
# 30         27.150897
# 73         31.309229
# 33         33.977711
# 90         17.391885
# 4          18.120373
# 76         30.425407
# 77         16.480893
# 12         31.648853
# 31         18.410482
# 55    3.378030
# 88    3.756114
# 26    1.727990
# 42    2.140188
# 69    3.864685
#         ...
# 60    1.885728
# 71    1.237203
# 14    1.912189
# 92    2.898876
# 51    2.767117
# Name: Energy Consumption (kWh), Length: 80, dtype: float64
# 83    1.955394
# 53    3.037917
# 70    2.426014
# 45    2.370351
# 44    2.413076
# 39    2.531079
# 22    2.086846
# 80    4.159094
# 10    1.998870
# 0     2.292604
# 18    2.167836
# 30    3.658183
# 73    3.279415
# 33    3.360548
# 90    2.150219
# 4     1.702201
# 76    2.702528
# 77    1.764216
# 12    2.900005
# 31    1.928337
# Name: Energy Consumption (kWh), dtype: float64
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
print(y_pred)
# Out:
# [1.6858187  3.18154068 2.96097494 2.76354868 2.0370856  2.36343345
#  2.09711944 3.12445907 1.60849483 2.24537556 2.34866555 2.66462648
#  3.0387357  3.27880886 1.78664542 1.85218469 2.95922164 1.70468695
#  3.0692904  1.87828475]

# %%
X_test
# Out:
#     Temperature (°C)
# 83         16.271167
# 53         32.896547
# 70         30.444895
# 45         28.250446
# 44         20.175600
# 39         23.803050
# 22         20.842893
# 80         32.262069
# 10         15.411690
# 0          22.490802
# 18         23.638900
# 30         27.150897
# 73         31.309229
# 33         33.977711
# 90         17.391885
# 4          18.120373
# 76         30.425407
# 77         16.480893
# 12         31.648853
# 31         18.410482

# %%
Y_test
# Out:
# 83    1.955394
# 53    3.037917
# 70    2.426014
# 45    2.370351
# 44    2.413076
# 39    2.531079
# 22    2.086846
# 80    4.159094
# 10    1.998870
# 0     2.292604
# 18    2.167836
# 30    3.658183
# 73    3.279415
# 33    3.360548
# 90    2.150219
# 4     1.702201
# 76    2.702528
# 77    1.764216
# 12    2.900005
# 31    1.928337
# Name: Energy Consumption (kWh), dtype: float64

# %%
mse= mean_squared_error(Y_test,y_pred)

print(f"Mean Squared Error:{mse}")

r2=r2_score(Y_test,y_pred)

print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error:0.16342487842925055
# R-Squared: 0.6119478445218713

# %%
plt.scatter(X_test, Y_test, color='blue', label='Test Data')

plt.plot(X_test, y_pred, color="red", label='Regression Line')

plt.xlabel('Temperature (°C)')

plt.ylabel('Energy Consumption (kWh)')

plt.legend()

plt.title("Energy Consumption Prediction using Simple Liner Regression")

plt.show()
